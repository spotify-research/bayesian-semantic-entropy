# %% [markdown]
# Reads pickle files and converts them into a dataset parseable by the notebook that does semantic entropy analysis.

# %%
import pickle

with open(f'/home/sinag/dev/llm-hallucination/.aim/86e1574943c649bb91dd3fe5/uncertainty_measures.pkl', 'rb') as file:
    results = pickle.load(file)

with open(f'/home/sinag/dev/llm-hallucination/.aim/86e1574943c649bb91dd3fe5/validation_generations.pkl', 'rb') as file:
    vg = pickle.load(file)

# %%
import numpy as np

is_hallucination = np.array(results['validation_is_false']) # One bit per question indicating if we a hallucination.
semantic_ids = np.array(results['semantic_ids']) # An array with smenatic ids for each question. Rows (the first index) are questions.
test_repsonse_list = [[vg[key]['responses'][generation_index][0] for generation_index in range(len(vg[key]['responses']))] for key in vg.keys()] # A nested list of model responses for ech question. The first index corresponds to questions.
generated_token_logits = [[vg[key]['responses'][generation_index][1] for generation_index in range(len(vg[key]['responses']))] for key in vg.keys()] # A nested list of model responses for ech question. The first index corresponds to questions.
p_false_fixed = results['uncertainty_measures']['p_false_fixed']
most_likely_answer = [vg[key]['most_likely_answer'] for key in vg.keys()]
questions = [vg[key]['question'] for key in vg.keys()]
contexts = [vg[key]['context'] for key in vg.keys()]

data_tuple = (is_hallucination, semantic_ids, test_repsonse_list, 
              generated_token_logits, p_false_fixed, most_likely_answer, questions, contexts)

# %%
with open('nnnp-Llama-3.2-3B-Instruct--trivia_qa--results.pickle', 'wb') as handle:
    pickle.dump(data_tuple, handle)

# %%
semantic_ids.shape
# Out:
# (10, 100)

# %%
generated_token_logits[0]
# Out:
# [[-1.7454102039337158,
#   -3.877537488937378,
#   -0.9139289259910583,
#   -2.3728697299957275,
#   -0.6527779698371887,
#   0.0,
#   -0.2631075382232666],
#  [-3.9759457111358643, -3.094034433364868, 0.0, -0.4019164741039276],
#  [-4.618583679199219, -0.16500307619571686, -0.3390474021434784],
#  [-4.292034149169922, -0.19516266882419586, -0.1031193733215332],
#  [-1.7454102039337158,
#   -3.1305596828460693,
#   -0.6020697355270386,
#   -0.30801811814308167,
#   0.0,
#   -3.481229782104492,
#   -1.09185791015625,
#   -0.19813205301761627,
#   -3.69175386428833,
#   -1.7131823301315308,
#   -1.3031010627746582,
#   -0.7180777788162231,
#   -1.6526917219161987,
#   -4.494382858276367,
#   -1.4869388341903687],
#  [-3.8099520206451416,
#   -0.4054338037967682,
#   -0.11912744492292404,
#   -0.4829406142234802,
#   -1.9064823389053345],
#  [-1.7454102039337158, -3.1305596828460693, -2.0623674392700195],
#  [-1.7454102039337158,
#   -4.385869979858398,
#   -0.04712286591529846,
#   0.0,
#   0.0,
#   -0.1578240841627121],
#  [-1.7454102039337158,
#   -3.514343023300171,
#   -0.6052485704421997,
#   -0.4928829073905945],
#  [-4.479267120361328, 0.0, -0.1167176365852356],
#  [-1.7454102039337158, -3.710181951522827, -0.3343487083911896],
#  [-2.0298378467559814,
#   -0.5149609446525574,
#   -4.385166645050049,
#   -0.41152116656303406,
#   -1.0084015130996704,
#   0.0,
