# %% [markdown]
# Reads pickle files and converts them into a dataset parseable by the notebook that does semantic entropy analysis.

# %%
import pickle

with open(f'/home/sinag/dev/llm-hallucination/.aim/bb68a730b3ab42ae9fe90df8/uncertainty_measures.pkl', 'rb') as file:
    results = pickle.load(file)

with open(f'/home/sinag/dev/llm-hallucination/.aim/bb68a730b3ab42ae9fe90df8/validation_generations.pkl', 'rb') as file:
    vg = pickle.load(file)

# %%
import numpy as np

is_hallucination = np.array(results['validation_is_false']) # One bit per question indicating if we a hallucination.
semantic_ids = np.array(results['semantic_ids']) # An array with smenatic ids for each question. Rows (the first index) are questions.
test_repsonse_list = [[vg[key]['responses'][generation_index][0] for generation_index in range(len(vg[key]['responses']))] for key in vg.keys()] # A nested list of model responses for ech question. The first index corresponds to questions.
generated_token_logits = [[vg[key]['responses'][generation_index][1] for generation_index in range(len(vg[key]['responses']))] for key in vg.keys()] # A nested list of model responses for ech question. The first index corresponds to questions.
p_false_fixed = results['uncertainty_measures']['p_false_fixed']
most_likely_answer = [vg[key]['most_likely_answer'] for key in vg.keys()]
questions = [vg[key]['question'] for key in vg.keys()]
contexts = [vg[key]['context'] for key in vg.keys()]

data_tuple = (is_hallucination, semantic_ids, test_repsonse_list, 
              generated_token_logits, p_false_fixed, most_likely_answer, questions, contexts)

# %%
with open('nnnp-Llama-2-7b-chat--trivia_qa--results.pickle', 'wb') as handle:
    pickle.dump(data_tuple, handle)

# %%
vg[list(vg.keys())[0]]
# Out:
# {'question': 'Who defeated Boris Spassky in a 1972 chess showdown?',
#  'context': '[DOC] [TLE] Boris Vasilyevich Spassky - Chess PlayerBoris Vasilyevich Spassky - Chess Player [PAR] Boris Vasilyevich Spassky [PAR] Chess Players [PAR] Boris Vasilyevich Spassky [PAR] Boris Spassky was born in the Soviet Union in 1937. He was the reigning World Chess Champion from 1969 (when he defeated Tigran Petrosyan) until 1972 (when he was defeated by Bobby Fischer). [PAR] Boris Spassky beat World Champion Mikhail Botvinnik in an exhibition at the age of ten, became International Master at age 16 and International Grandmaster at age 18. He qualified for this first Candidates Tournament when he was 20 years old, and won his first USSR Championship four years later. [PAR] Boris Spassky moved settled down outside Paris with his third wife in the 1970s. He has been a French citizen since 1978. [PAR] Background and early chess [PAR] Boris Vasilyevich Spassky was born in Leningrad (today known as St Petersburg) in the Soviet Union on January 30, 1937. In 1942, the Spassky family fled their hometown because of the Nazi siege. Young Boris learned to play chess while on a train. The family eventually settled down in Kirov, but life there was hard for them. Boris kept on playing chess, and at the tender age of 10 he managed to defeat World Champion Mikhail Botvinnik in an exhibition. [PAR] Early Chess Career [PAR] In 1953, the 16 year old Spassky had great success in a tournament in Bucharest, Romania, and earned the rank of International Master. ',
#  'most_likely_answer': {'response': 'Bobby Fischer',
#   'token_log_likelihoods': [0.0, 0.0, 0.0],
#   'embedding': tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#   'accuracy': 1.0},
#  'reference': {'answers': {'answer_start': [358], 'text': ['bobby fischer']},
#   'id': 'jp_1630--10/10_1391268.txt#0_0'},
#  'responses': [('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fisher',
#    [0.0, -2.743300676345825, 0.0, 0.0],
#    tensor([[ 0.8790, -0.8953, -1.3618,  ..., -0.9679, -0.6302,  1.0894]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fisher',
#    [0.0, -2.743300676345825, 0.0, 0.0],
#    tensor([[ 0.8790, -0.8953, -1.3618,  ..., -0.9679, -0.6302,  1.0894]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fisher',
#    [0.0, -2.743300676345825, 0.0, 0.0],
#    tensor([[ 0.8790, -0.8953, -1.3618,  ..., -0.9679, -0.6302,  1.0894]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fisher',
#    [0.0, -2.743300676345825, 0.0, 0.0],
#    tensor([[ 0.8790, -0.8953, -1.3618,  ..., -0.9679, -0.6302,  1.0894]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -2.464923620223999],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0),
#   ('Bobby Fischer',
#    [0.0, -0.06652188301086426, -0.08884794265031815],
#    tensor([[ 0.8307,  0.7504,  2.4853,  ..., -0.2417,  0.2334,  0.1754]]),
#    1.0)]}
